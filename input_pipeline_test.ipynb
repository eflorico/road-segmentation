# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from input_pipeline import input_pipeline_train, input_pipeline_test, load_data

# %%
X, Y, X_test = load_data()

# %%
train_gen = input_pipeline_train(X, Y,
                                reduce_to_patches=False,
                                two_classes=True,
                                return_weights=True,
                                augment_borders=True)
X_batch, Y_batch, W_batch = next(train_gen)
i = 0
# Out:
# 100%|██████████| 100/100 [00:29<00:00,  3.18it/s]
# Augmented borders, generated 998920 patches
# Class weights: non-road 0.811, road 0.189

# %%
plt.figure(figsize=(10, 10))
plt.imshow(X_batch[i])
plt.figure()
plt.imshow(Y_batch[i,:,:,1])
i+=1

# %%
test_gen = input_pipeline_test(X, Y, 
                               reduce_to_patches=False, 
                               two_classes=False)
X_batch, Y_batch = next(test_gen)
i = 0

# %%
plt.figure(figsize=(10, 10))
plt.imshow(X_batch[i])
plt.figure()
plt.imshow(Y_batch[i])
i+=1

# %%
import models
# Out:
# Using TensorFlow backend.

# %%
len(models.unet().output_shape)
# Out:
# 4
